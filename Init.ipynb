# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://deepnote.com/docs/project-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here.
# if test -f requirements.txt
#   then
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install."
# fi
# Out:
# Collecting imblearn==0.0 (from -r ./requirements.txt (line 2))
#   Downloading imblearn-0.0-py2.py3-none-any.whl.metadata (355 bytes)
# Collecting imbalanced-learn (from imblearn==0.0->-r ./requirements.txt (line 2))
#   Downloading imbalanced_learn-0.14.1-py3-none-any.whl.metadata (8.9 kB)
# Requirement already satisfied: numpy<3,>=1.25.2 in /root/venv/lib/python3.11/site-packages (from imbalanced-learn->imblearn==0.0->-r ./requirements.txt (line 2)) (1.26.4)
# Requirement already satisfied: scipy<2,>=1.11.4 in /root/venv/lib/python3.11/site-packages (from imbalanced-learn->imblearn==0.0->-r ./requirements.txt (line 2)) (1.11.4)
# Collecting scikit-learn<2,>=1.4.2 (from imbalanced-learn->imblearn==0.0->-r ./requirements.txt (line 2))
#   Downloading scikit_learn-1.8.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (11 kB)
# Collecting sklearn-compat<0.2,>=0.1.5 (from imbalanced-learn->imblearn==0.0->-r ./requirements.txt (line 2))
#   Downloading sklearn_compat-0.1.5-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: joblib<2,>=1.2.0 in /root/venv/lib/python3.11/site-packages (from imbalanced-learn->imblearn==0.0->-r ./requirements.txt (line 2)) (1.5.3)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in /root/venv/lib/python3.11/site-packages (from imbalanced-learn->imblearn==0.0->-r ./requirements.txt (line 2)) (3.6.0)
# Downloading imblearn-0.0-py2.py3-none-any.whl (1.9 kB)
# Downloading imbalanced_learn-0.14.1-py3-none-any.whl (235 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.4/235.4 kB 10.7 MB/s eta 0:00:00
# Downloading scikit_learn-1.8.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (9.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 92.1 MB/s eta 0:00:00
# Downloading sklearn_compat-0.1.5-py3-none-any.whl (20 kB)
# Installing collected packages: scikit-learn, sklearn-compat, imbalanced-learn, imblearn
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.3.2
#     Uninstalling scikit-learn-1.3.2:
#       Successfully uninstalled scikit-learn-1.3.2
# Successfully installed imbalanced-learn-0.14.1 imblearn-0.0 scikit-learn-1.8.0 sklearn-compat-0.1.5
#
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
